# %% [markdown]
# # 1. Cargando base de datos

# %%
import pandas as pd

# %%
import numpy as np

# %%
# Read the database from the .csv file into a pandas dataframe
df = pd.read_csv('../../databases/insurance.csv')

# %% [markdown]
# # 2. Preprocesamiento de los datos

# %%
from sklearn import preprocessing

# %% [markdown]
# ## 2.1. Codificación de variables no numéricas

# %%
# Create a label encoder for the sex variable or feature and create a new column in the dataframe 
# with the encoded version of the gender
sex_encoder = preprocessing.LabelEncoder()
sex_encoder.fit(df['sex'])
df['sex-encoded'] = sex_encoder.transform(df['sex'])

# %%
# Create a label encoder for the smoker variable or feature and create a new column in the dataframe
# with the encoded version of the smoker
smoker_encoder = preprocessing.LabelEncoder()
smoker_encoder.fit(df['smoker'])
df['smoker-encoded'] = smoker_encoder.transform(df['smoker'])

# %%
# Create a one hot encoder and fit the available types of regions in the dataset
region_encoder = preprocessing.OneHotEncoder()
region_encoder.fit(df['region'].to_numpy().reshape(-1, 1))

# Transform all entries into the one hot encoded representation
encoded_regions = region_encoder.transform(df['region'].to_numpy().reshape(-1, 1)).toarray()

# Add each new encoded variable or feature to the dataset
for i, category in enumerate(region_encoder.categories_[0]):
    df[f'{category}-encoded'] = encoded_regions.transpose()[i]

# %% [markdown]
# ## 2.2. Filtrado o eliminación de variables no necesarias

# %%
# Declare the selected variables to be used
x_variables = ['age', 'bmi', 'smoker-encoded', 'children', 'sex-encoded', 'northwest-encoded', 'northeast-encoded', 'southwest-encoded', 'southeast-encoded']
y_variables = ['charges']

# Filtering or removing of non desired variables
df_x = df[x_variables]
df_y = df[y_variables]

# %% [markdown]
# # 3. Separación del conjunto de entrenamiento y evaluación

# %%
from sklearn import model_selection

# %%
from sklearn import preprocessing

# %% [markdown]
# ## 3.1. Separación de los conjuntos

# %%
# Split the dataset into train and test
x_train, x_test, y_train, y_test = model_selection.train_test_split(df_x.to_numpy(), df_y.to_numpy(), test_size=0.2, random_state=3, shuffle=True)

# %% [markdown]
# ## 3.2. Normalización de variables

# %%
# Create an instance of the StandardScaler for each variable
scaler = preprocessing.StandardScaler()

# Fit the distribution
scaler.fit(x_train)

# Transform and normalize all variables
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# # 4. Regresión Lineal

# %%
from tensorflow import keras

# %%
from sklearn import metrics

# %% [markdown]
# ## 4.1 Creando el modelo en Keras

# %%
# Create the sequential stack of dense layers as a model
model = keras.Sequential()
model.add(keras.layers.Dense(1, input_shape=(df_x.shape[1],)))

# Define the loss function and the optimizer used
model.compile(optimizer='sgd', loss='mse')

# %% [markdown]
# ## 4.2 Entrenando el modelo en Keras

# %%
# Create the callback for the TensorBoard
tb_callback = keras.callbacks.TensorBoard('./logs', update_freq=1)

# Training the model
model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, verbose=1, batch_size=64, shuffle=True, callbacks=[tb_callback])
# Out:
# Epoch 1/100
# 17/17 [==============================] - 2s 79ms/step - loss: 270160974.2222 - val_loss: 185917952.0000
# Epoch 2/100
# 17/17 [==============================] - 0s 8ms/step - loss: 159115856.0000 - val_loss: 113844176.0000
# Epoch 3/100
# 17/17 [==============================] - 0s 12ms/step - loss: 93684967.1111 - val_loss: 77467208.0000
# Epoch 4/100
# 17/17 [==============================] - 0s 5ms/step - loss: 37400295.7778 - val_loss: 39222372.0000
# Epoch 87/100
# 17/17 [==============================] - 0s 6ms/step - loss: 39584462.6667 - val_loss: 39211664.0000
# Epoch 88/100
# 17/17 [==============================] - 0s 6ms/step - loss: 36538393.1111 - val_loss: 39197228.0000
# Epoch 89/100
# 17/17 [==============================] - 0s 4ms/step - loss: 38034577.7778 - val_loss: 39163968.0000
# Epoch 90/100
# 17/17 [==============================] - 0s 5ms/step - loss: 37390549.1111 - val_loss: 39214940.0000
# Epoch 91/100
# 17/17 [==============================] - 0s 5ms/step - loss: 38494693.3333 - val_loss: 39232980.0000
# Epoch 92/100
# 17/17 [==============================] - 0s 9ms/step - loss: 33894226.4444 - val_loss: 39270668.0000
# Epoch 93/100
# 17/17 [==============================] - 0s 6ms/step - loss: 34930193.1111 - val_loss: 39265148.0000
# Epoch 94/100
# 17/17 [==============================] - 0s 6ms/step - loss: 33852749.3333 - val_loss: 39257728.0000
# Epoch 95/100
# 17/17 [==============================] - 0s 7ms/step - loss: 34855589.1111 - val_loss: 39222464.0000
# Epoch 96/100
# 17/17 [==============================] - 0s 7ms/step - loss: 39300687.3333 - val_loss: 39198404.0000
# Epoch 97/100
# 17/17 [==============================] - 0s 8ms/step - loss: 34367878.6667 - val_loss: 39201800.0000
# Epoch 98/100
# 17/17 [==============================] - 0s 9ms/step - loss: 33906961.5556 - val_loss: 39182856.0000
# Epoch 99/100
# 17/17 [==============================] - 0s 8ms/step - loss: 34966146.2222 - val_loss: 39213296.0000
# Epoch 100/100
# 17/17 [==============================] - 0s 9ms/step - loss: 37362612.5556 - val_loss: 39205136.0000

# %%
y_pred = model.predict(x_test)

# %%
metrics.mean_absolute_error(y_test, y_pred)
# Out:
# 4239.128226779151

# %%
import matplotlib.pyplot as plt

# %%
# Compute the error
error = y_test - y_pred

# Compute the absolute error
absolute_error = abs(error)

# Compute the accumulative the error
accumulative_error = np.zeros(len(absolute_error))
for i in range(len(absolute_error)):
    if i == 0:
        accumulative_error[i] = absolute_error[i]
    else:
        accumulative_error[i] = accumulative_error[i-1] + absolute_error[i]

# Compute the mean absolute error through the samples
mean_absolute_error = np.zeros(len(accumulative_error))
for i in range(len(accumulative_error)):
    mean_absolute_error[i] = accumulative_error[i] / (i + 1)

# %%
# Create plots and layout
fig, ax = plt.subplots(2, 1, figsize=(18, 12))

# Plot the real and the prediction
ax[0].plot(y_test, marker='o', label='Real')
ax[0].plot(y_pred, marker='o', label='Predicción')
ax[0].set_xlabel('$n$', fontsize=15)
ax[0].set_ylabel('Costo atención médica', fontsize=15)
ax[0].legend(fontsize=12)
ax[0].grid()

# Plot the absolute error and the evolution of the mean absolute error throughout the dataset
ax[1].plot(absolute_error, label='Error absoluto')
ax[1].plot(mean_absolute_error, label='Error absolute medio')
ax[1].legend(fontsize=12)
ax[1].grid()

# Show the graph
plt.show()

# %%
model.get_weights()
# Out:
# [array([[3678.6372 ],
#         [2123.1719 ],
#         [9595.179  ],
#         [ 677.74646],
#         [-101.39879],
#         [ 111.01181],
#         [ 277.87192],
#         [-129.75296],
#         [-244.5785 ]], dtype=float32),
#  array([13223.509], dtype=float32)]
